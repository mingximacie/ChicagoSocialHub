# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### <center> Divvy Docking Stations </center>
# ### <center> Postgres and ElatsicSearch </center>
#
#
# **Author: Atef Bader, PhD**
#
# **Last Edit: 10/18/2022**
#
# <br>
#     <br>
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
#
#
#
# ## High-level Description:
# - This script collects Divvy Docking Stations real-time data for the city of Chicago  area from Divvy servers
# - Use **Postgres** to store real-time status of every docking stattion in Chicago every 2 minutes
# - Use **ElasticSearch** to store every reported status of every docking stattion in Chicago every 2 minutes in a log file
#
#
# - This python script will send a heartbeat to Divvy every 2 minutes to retrieve the  status of the Divvy dock stations and store the data on PostgreSQL server.
#
#
#
# </br>
# </br>
#
# </div>
#
# <hr style="border:5px solid orange"> </hr>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
#
#
#
# ## Divvy
#
# **Divvy** is a bicycle sharing system in the City of Chicago.
#
# Click __[here](https://en.wikipedia.org/wiki/Divvy)__ to read more about **Divvy**
#
#
# Click __[here](https://www.divvybikes.com/)__ to visit the official website for **Divvy**
#
#
# </br>
# </br>
#
# </div>
#
# <hr style="border:5px solid orange"> </hr>

# %% [markdown]
# <div class="alert alert-info">
#
# ### PostgreSQL
#
# - We will collect the data from **Divvy** servers and store the data in a table on **PostgreSQL** server.
#
# - Install and use Postgres release 10 or 13 from Posgres (https://www.postgresql.org/download/)
# - You need the package **psycopg2** to Connect to **PostgreSQL** server.
#
#
#
# - Execute the **pip install** command from the command window to install  the package listed bove:
#  - pip install psycopg2
#
#
#
# </br>
#
#
# </div>
#
#
#
#
# <hr style="border:5px solid orange"> </hr>

# %% [markdown]
# <div class="alert alert-info">
#
# ### ElasticSearch
#
# - We will collect the data from **Divvy** servers and store the data in a log (collection/index) of every reported real-time status heartbeat) on **PostgreSQL** server.
# - Install and Use ElasticSesarch 7.14.0 from ElasticSearch (https://www.elastic.co/downloads/past-releases/elasticsearch-7-14-0)
#
#
# - Execute the **pip install** command from the command window to install  the package listed bove:
#  - pip install elasticsearch
#
#
#
# </br>
#
#
# </div>
#
#
#
#
# <hr style="border:5px solid orange"> </hr>

# %%
# !pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages (2.9.4)

# %%
pip install elasticsearch
# Out:
# Requirement already satisfied: elasticsearch in /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages (7.13.3)
# Requirement already satisfied: certifi in /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages (from elasticsearch) (2021.10.8)
# Requirement already satisfied: urllib3<2,>=1.21.1 in /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages (from elasticsearch) (1.26.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
import requests
import datetime
import time
import os
import psycopg2
import pandas as pd
from urllib.request import urlopen
import json
import csv
from pprint import pprint
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT 
from datetime import datetime

# %%
from elasticsearch import Elasticsearch, helpers 

es = Elasticsearch('http://localhost:9200')

# %%
def set_data(input_file, index_name = "divvy_station_logs", doc_type_name="log"):
    for line in input_file:
        
        yield {
            "_index": index_name,
            "_type": doc_type_name,
            "_source": line
            
        }

# %%
def load(es, input_file, **kwargs):
    success, _ = helpers.bulk(es, set_data(input_file, **kwargs))

# %%
# Get divvy statations status
# Status is returned as a json reply

# response = urlopen('https://feeds.divvybikes.com/stations/stations.json')

response_stations_info = urlopen('https://gbfs.divvybikes.com/gbfs/en/station_information.json')

response = urlopen('https://gbfs.divvybikes.com/gbfs/en/station_status.json')

# Extract the body of the reply
response_body = response.read()
response_stations_info = response_stations_info.read()

# Decode the format in json format
stations_json = json.loads(response_body.decode("utf-8"))
stations_info_json = json.loads(response_stations_info.decode("utf-8"))

# %%
pprint(stations_json)
# Out:
# {'data': {'stations': [{'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690409,
#                         'legacy_id': '145',
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 3,
#                         'num_docks_available': 13,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 3,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3a62566-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690412,
#                         'legacy_id': '135',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 11,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': 'a3a5f5e6-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690417,
#                         'legacy_id': '465',
#                         'num_bikes_available': 7,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 16,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3af52bc-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690420,
#                         'legacy_id': '237',
#                         'num_bikes_available': 4,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 15,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 4,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3a859c4-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690420,
#                         'legacy_id': '678',
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 12,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a60781db-2bec-4a15-a4a2-363297aefcec',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690420,
#                         'legacy_id': '578',
#                         'num_bikes_available': 6,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 5,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3b2862e-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690418,
#                         'legacy_id': '407',
#                         'num_bikes_available': 4,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 7,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3ad2d57-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690418,
#                         'legacy_id': '198',
#                         'num_bikes_available': 13,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 14,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 2,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3a79adb-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690423,
#                         'legacy_id': '451',
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 20,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 2,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3ae87fa-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690429,
#                         'legacy_id': '458',
#                         'num_bikes_available': 10,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 8,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 2,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3af2c5f-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690429,
#                         'legacy_id': '327',
#                         'num_bikes_available': 7,
#                         'num_bikes_disabled': 3,
#                         'num_docks_available': 9,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 2,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3aabad8-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690427,
#                         'legacy_id': '323',
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 15,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 2,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3aaa68b-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690427,
#                         'legacy_id': '643',
#                         'num_bikes_available': 4,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 11,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 3,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3b4399a-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690425,
#                         'legacy_id': '723',
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 6,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'da9e6779-5056-4d45-bae3-9dc325ed2807',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690426,
#                         'legacy_id': '421',
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 6,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3ad7636-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690431,
#                         'legacy_id': '273',
#                         'num_bikes_available': 7,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 14,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'num_scooters_available': 1,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3a99d47-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690432,
#                         'legacy_id': '441',
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 8,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 2,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3addda0-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690432,
#                         'legacy_id': '540',
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 8,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3b148bf-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690432,
#                         'legacy_id': '554',
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 1,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3b20960-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690437,
#                         'legacy_id': '16',
#                         'num_bikes_available': 4,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 8,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'num_scooters_available': 2,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3a3b202-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690437,
#                         'legacy_id': '525',
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 12,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3b0fae6-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690434,
#                         'legacy_id': '96',
#                         'num_bikes_available': 8,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 14,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3a52df5-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690445,
#                         'legacy_id': '631',
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 16,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'num_scooters_available': 1,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3b3915a-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690450,
#                         'legacy_id': '335',
#                         'num_bikes_available': 1,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 14,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3aae35a-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690451,
#                         'legacy_id': '13',
#                         'num_bikes_available': 11,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 23,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 2,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3a3a282-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690450,
#                         'legacy_id': '261',
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 10,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 2,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3a965b2-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690450,
#                         'legacy_id': '621',
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 9,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'num_scooters_available': 2,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3b3634c-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690447,
#                         'legacy_id': '367',
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 10,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 2,
#                         'num_scooters_available': 1,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3ac7e9a-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690448,
#                         'legacy_id': '491',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 15,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': 'a3afd7ab-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690452,
#                         'legacy_id': '277',
#                         'num_bikes_available': 10,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 1,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'num_scooters_available': 3,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3a9b1d7-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690454,
#                         'legacy_id': '60',
#                         'num_bikes_available': 6,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 10,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 5,
#                         'num_scooters_available': 2,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3a497b6-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690457,
#                         'legacy_id': '544',
#                         'num_bikes_available': 1,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 10,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3b1d532-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690457,
#                         'legacy_id': '15',
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 2,
#                         'num_docks_available': 8,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3a3ace6-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690453,
#                         'legacy_id': '352',
#                         'num_bikes_available': 1,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 10,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3ac35ed-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690460,
#                         'legacy_id': '227',
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 4,
#                         'num_docks_available': 14,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3a82c6c-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690461,
#                         'legacy_id': '530',
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 6,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3b11480-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690461,
#                         'legacy_id': '479',
#                         'num_bikes_available': 6,
#                         'num_bikes_disabled': 2,
#                         'num_docks_available': 7,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 5,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3af9a83-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690464,
#                         'legacy_id': '197',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 16,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'num_scooters_available': 3,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3a795d7-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690465,
#                         'legacy_id': '559',
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 8,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3b222fc-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690465,
#                         'legacy_id': '594',
#                         'num_bikes_available': 4,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 7,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3b2d7d9-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690465,
#                         'legacy_id': '538',
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 8,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 3,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3b13e66-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690469,
#                         'legacy_id': '378',
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 9,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 2,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3acb1de-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690469,
#                         'legacy_id': '657',
#                         'num_bikes_available': 7,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 7,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 5,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3b481e1-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690466,
#                         'legacy_id': '637',
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 10,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'num_scooters_available': 1,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3b419d9-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690465,
#                         'legacy_id': '365',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 14,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'num_scooters_available': 1,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3ac7444-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690468,
#                         'legacy_id': '290',
#                         'num_bikes_available': 6,
#                         'num_bikes_disabled': 2,
#                         'num_docks_available': 6,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 4,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3a9f76a-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690468,
#                         'legacy_id': '659',
#                         'num_bikes_available': 11,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 7,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 7,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3b48c07-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690476,
#                         'legacy_id': '245',
#                         'num_bikes_available': 8,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 15,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3a8855c-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690474,
#                         'legacy_id': '684',
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 13,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'f0f9f5dc-3d3f-4a32-aa3e-b87566e44de9',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690475,
#                         'legacy_id': '34',
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 2,
#                         'num_docks_available': 8,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 4,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3a41004-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690473,
#                         'legacy_id': '142',
#                         'num_bikes_available': 1,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 29,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3a614ad-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690473,
#                         'legacy_id': '715',
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 2,
#                         'num_docks_available': 10,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 2,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': '732c9f35-0c82-4128-acc3-2cf447298b1d',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690473,
#                         'legacy_id': '249',
#                         'num_bikes_available': 7,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 23,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 4,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3a8999a-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 0,
#                         'is_returning': 0,
#                         'last_reported': 1667690474,
#                         'legacy_id': '146',
#                         'num_bikes_available': 4,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 15,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3a62aad-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690471,
#                         'legacy_id': '467',
#                         'num_bikes_available': 6,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 8,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 6,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3af5d1c-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690471,
#                         'legacy_id': '537',
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 9,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3b13836-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690472,
#                         'legacy_id': '172',
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 2,
#                         'num_docks_available': 6,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 2,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3a72012-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690470,
#                         'legacy_id': '591',
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 11,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3b2c87c-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690472,
#                         'legacy_id': '131',
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 10,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 2,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3a5de24-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690479,
#                         'legacy_id': '215',
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 11,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 3,
#                         'num_scooters_available': 1,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3a7f0ba-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690480,
#                         'legacy_id': '656',
#                         'num_bikes_available': 4,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 7,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'num_scooters_available': 3,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3b47cbc-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690480,
#                         'legacy_id': '108',
#                         'num_bikes_available': 17,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 1,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 6,
#                         'num_scooters_available': 1,
#                         'num_scooters_unavailable': 0,
#                         'station_id': 'a3a565b1-a135-11e9-9cda-0a87ae2ba916',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1667690477,
#                         'legacy_id': '17',
# ...
#                         'last_reported': 1662499189,
#                         'legacy_id': '1677249772289529866',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 1,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '1677249772289529866',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1662488326,
#                         'legacy_id': '1674190376985963172',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 1,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '1674190376985963172',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1662511154,
#                         'legacy_id': '1683527957294958598',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 1,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '1683527957294958598',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1662483612,
#                         'legacy_id': '1674190239547009454',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 1,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '1674190239547009454',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666284406,
#                         'legacy_id': '1575949498093662914',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 9,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '1575949498093662914',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666284407,
#                         'legacy_id': '1594046418168009436',
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 7,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 2,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': '1594046418168009436',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1662511130,
#                         'legacy_id': '1695776956346497674',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 1,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '1695776956346497674',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1662499155,
#                         'legacy_id': '1674190235252042148',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 4,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '1674190235252042148',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1662498659,
#                         'legacy_id': '1674190170827532590',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 1,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '1674190170827532590',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1662486849,
#                         'legacy_id': '1674190557374589898',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 2,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': '1674190557374589898',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666284405,
#                         'legacy_id': '1594046418168009438',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 9,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '1594046418168009438',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1662499196,
#                         'legacy_id': '1677249776584497168',
#                         'num_bikes_available': 1,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 1,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': '1677249776584497168',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666284402,
#                         'legacy_id': '1594046456822715150',
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 4,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 5,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': '1594046456822715150',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1662486462,
#                         'legacy_id': '1674190535899753382',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 1,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '1674190535899753382',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1662484222,
#                         'legacy_id': '1674190291086617090',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 2,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '1674190291086617090',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1662498427,
#                         'legacy_id': '1674190157942630672',
#                         'num_bikes_available': 1,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 0,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': '1674190157942630672',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1662486213,
#                         'legacy_id': '1674190492950080350',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 1,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '1674190492950080350',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1662511992,
#                         'legacy_id': '1677249879663712418',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 1,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '1677249879663712418',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1662489425,
#                         'legacy_id': '1715846688321143644',
#                         'num_bikes_available': 1,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 0,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': '1715846688321143644',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1662489397,
#                         'legacy_id': '1715823822654071770',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 1,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '1715823822654071770',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1666284406,
#                         'legacy_id': '1563698701206292480',
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 7,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 2,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': '1563698701206292480',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1662512058,
#                         'legacy_id': '1674190591734328324',
#                         'num_bikes_available': 1,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 1,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'num_scooters_available': 0,
#                         'num_scooters_unavailable': 0,
#                         'station_id': '1674190591734328324',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1662513165,
#                         'legacy_id': '1674190634684001360',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 2,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '1674190634684001360',
#                         'station_status': 'active'}]},
#  'last_updated': 1667690540,
#  'ttl': 5}

# %%
pprint(stations_info_json)

# %%
db_connection = psycopg2.connect(host='127.0.0.1',dbname="postgres", user="postgres" , password="root")

# %%
db_connection.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT) 

cursor = db_connection.cursor()

# %%
# uncomment the following line if you already created the database 
# Only once you need to create the database

cursor.execute("CREATE DATABASE chicago_divvy_stations_status;")
db_connection.commit()
# Out:
# ---------------------------------------------------------------------------
# DuplicateDatabase                         Traceback (most recent call last)
# /Users/mingxi/Downloads/Assignment/AS4/backend-build-divvy-status/divvy_real-time_status.ipynb Cell 17 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/Users/mingxi/Downloads/Assignment/AS4/backend-build-divvy-status/divvy_real-time_status.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> # uncomment the following line if you already created the database
#       <a href='vscode-notebook-cell:/Users/mingxi/Downloads/Assignment/AS4/backend-build-divvy-status/divvy_real-time_status.ipynb#X22sZmlsZQ%3D%3D?line=1'>2</a> # Only once you need to create the database
# ----> <a href='vscode-notebook-cell:/Users/mingxi/Downloads/Assignment/AS4/backend-build-divvy-status/divvy_real-time_status.ipynb#X22sZmlsZQ%3D%3D?line=3'>4</a> cursor.execute("CREATE DATABASE chicago_divvy_stations_status;")
#       <a href='vscode-notebook-cell:/Users/mingxi/Downloads/Assignment/AS4/backend-build-divvy-status/divvy_real-time_status.ipynb#X22sZmlsZQ%3D%3D?line=4'>5</a> db_connection.commit()
#
# DuplicateDatabase: database "chicago_divvy_stations_status" already exists

# %%
db_connection = psycopg2.connect(host='127.0.0.1',dbname="chicago_divvy_stations_status", user="postgres" , password="root")

cursor = db_connection.cursor()

# %%
# Only once you need to create the postgis extension.
# Comment the following line if you already created the postgis extension

cursor.execute("CREATE EXTENSION postgis;")
# Out:
# ---------------------------------------------------------------------------
# DuplicateObject                           Traceback (most recent call last)
# /Users/mingxi/Downloads/Assignment/AS4/backend-build-divvy-status/divvy_real-time_status.ipynb Cell 19 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/Users/mingxi/Downloads/Assignment/AS4/backend-build-divvy-status/divvy_real-time_status.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> # Only once you need to create the postgis extension.
#       <a href='vscode-notebook-cell:/Users/mingxi/Downloads/Assignment/AS4/backend-build-divvy-status/divvy_real-time_status.ipynb#X24sZmlsZQ%3D%3D?line=1'>2</a> # Comment the following line if you already created the postgis extension
# ----> <a href='vscode-notebook-cell:/Users/mingxi/Downloads/Assignment/AS4/backend-build-divvy-status/divvy_real-time_status.ipynb#X24sZmlsZQ%3D%3D?line=3'>4</a> cursor.execute("CREATE EXTENSION postgis;")
#
# DuplicateObject: extension "postgis" already exists

# %%
db_connection.commit()

# %%
cursor.execute("DROP TABLE IF EXISTS divvy_stations_realtime_status")

# %%
db_connection.commit()

# %%
cursor.execute("""CREATE TABLE divvy_stations_realtime_status(
                altitude FLOAT,
                availableBikes INTEGER,
                availableDocks INTEGER,
                city TEXT,
                id BIGINT,
                is_renting BOOLEAN,
                kioskType TEXT,
                landMark TEXT,
                lastCommunicationTime timestamp,
                latitude FLOAT,
                location TEXT,
                longitude FLOAT,
                postalCode INTEGER,
                stAddress1 TEXT,
                stAddress2 TEXT,
                stationName TEXT,
                status TEXT,
                statusKey INTEGER,
                statusValue TEXT,
                testStation BOOLEAN,
                totalDocks INTEGER,
                Where_IS GEOGRAPHY);""")
# Out:
# ---------------------------------------------------------------------------
# DuplicateTable                            Traceback (most recent call last)
# /Users/mingxi/Downloads/Assignment/AS4/backend-build-divvy-status/divvy_real-time_status.ipynb Cell 23 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/mingxi/Downloads/Assignment/AS4/backend-build-divvy-status/divvy_real-time_status.ipynb#X31sZmlsZQ%3D%3D?line=0'>1</a> cursor.execute("""CREATE TABLE divvy_stations_realtime_status(
#       <a href='vscode-notebook-cell:/Users/mingxi/Downloads/Assignment/AS4/backend-build-divvy-status/divvy_real-time_status.ipynb#X31sZmlsZQ%3D%3D?line=1'>2</a>                 altitude FLOAT,
#       <a href='vscode-notebook-cell:/Users/mingxi/Downloads/Assignment/AS4/backend-build-divvy-status/divvy_real-time_status.ipynb#X31sZmlsZQ%3D%3D?line=2'>3</a>                 availableBikes INTEGER,
#       <a href='vscode-notebook-cell:/Users/mingxi/Downloads/Assignment/AS4/backend-build-divvy-status/divvy_real-time_status.ipynb#X31sZmlsZQ%3D%3D?line=3'>4</a>                 availableDocks INTEGER,
#       <a href='vscode-notebook-cell:/Users/mingxi/Downloads/Assignment/AS4/backend-build-divvy-status/divvy_real-time_status.ipynb#X31sZmlsZQ%3D%3D?line=4'>5</a>                 city TEXT,
#       <a href='vscode-notebook-cell:/Users/mingxi/Downloads/Assignment/AS4/backend-build-divvy-status/divvy_real-time_status.ipynb#X31sZmlsZQ%3D%3D?line=5'>6</a>                 id BIGINT,
#       <a href='vscode-notebook-cell:/Users/mingxi/Downloads/Assignment/AS4/backend-build-divvy-status/divvy_real-time_status.ipynb#X31sZmlsZQ%3D%3D?line=6'>7</a>                 is_renting BOOLEAN,
#       <a href='vscode-notebook-cell:/Users/mingxi/Downloads/Assignment/AS4/backend-build-divvy-status/divvy_real-time_status.ipynb#X31sZmlsZQ%3D%3D?line=7'>8</a>                 kioskType TEXT,
#       <a href='vscode-notebook-cell:/Users/mingxi/Downloads/Assignment/AS4/backend-build-divvy-status/divvy_real-time_status.ipynb#X31sZmlsZQ%3D%3D?line=8'>9</a>                 landMark TEXT,
#      <a href='vscode-notebook-cell:/Users/mingxi/Downloads/Assignment/AS4/backend-build-divvy-status/divvy_real-time_status.ipynb#X31sZmlsZQ%3D%3D?line=9'>10</a>                 lastCommunicationTime timestamp,
#      <a href='vscode-notebook-cell:/Users/mingxi/Downloads/Assignment/AS4/backend-build-divvy-status/divvy_real-time_status.ipynb#X31sZmlsZQ%3D%3D?line=10'>11</a>                 latitude FLOAT,
#      <a href='vscode-notebook-cell:/Users/mingxi/Downloads/Assignment/AS4/backend-build-divvy-status/divvy_real-time_status.ipynb#X31sZmlsZQ%3D%3D?line=11'>12</a>                 location TEXT,
#      <a href='vscode-notebook-cell:/Users/mingxi/Downloads/Assignment/AS4/backend-build-divvy-status/divvy_real-time_status.ipynb#X31sZmlsZQ%3D%3D?line=12'>13</a>                 longitude FLOAT,
#      <a href='vscode-notebook-cell:/Users/mingxi/Downloads/Assignment/AS4/backend-build-divvy-status/divvy_real-time_status.ipynb#X31sZmlsZQ%3D%3D?line=13'>14</a>                 postalCode INTEGER,
#      <a href='vscode-notebook-cell:/Users/mingxi/Downloads/Assignment/AS4/backend-build-divvy-status/divvy_real-time_status.ipynb#X31sZmlsZQ%3D%3D?line=14'>15</a>                 stAddress1 TEXT,
#      <a href='vscode-notebook-cell:/Users/mingxi/Downloads/Assignment/AS4/backend-build-divvy-status/divvy_real-time_status.ipynb#X31sZmlsZQ%3D%3D?line=15'>16</a>                 stAddress2 TEXT,
#      <a href='vscode-notebook-cell:/Users/mingxi/Downloads/Assignment/AS4/backend-build-divvy-status/divvy_real-time_status.ipynb#X31sZmlsZQ%3D%3D?line=16'>17</a>                 stationName TEXT,
#      <a href='vscode-notebook-cell:/Users/mingxi/Downloads/Assignment/AS4/backend-build-divvy-status/divvy_real-time_status.ipynb#X31sZmlsZQ%3D%3D?line=17'>18</a>                 status TEXT,
#      <a href='vscode-notebook-cell:/Users/mingxi/Downloads/Assignment/AS4/backend-build-divvy-status/divvy_real-time_status.ipynb#X31sZmlsZQ%3D%3D?line=18'>19</a>                 statusKey INTEGER,
#      <a href='vscode-notebook-cell:/Users/mingxi/Downloads/Assignment/AS4/backend-build-divvy-status/divvy_real-time_status.ipynb#X31sZmlsZQ%3D%3D?line=19'>20</a>                 statusValue TEXT,
#      <a href='vscode-notebook-cell:/Users/mingxi/Downloads/Assignment/AS4/backend-build-divvy-status/divvy_real-time_status.ipynb#X31sZmlsZQ%3D%3D?line=20'>21</a>                 testStation BOOLEAN,
#      <a href='vscode-notebook-cell:/Users/mingxi/Downloads/Assignment/AS4/backend-build-divvy-status/divvy_real-time_status.ipynb#X31sZmlsZQ%3D%3D?line=21'>22</a>                 totalDocks INTEGER,
#      <a href='vscode-notebook-cell:/Users/mingxi/Downloads/Assignment/AS4/backend-build-divvy-status/divvy_real-time_status.ipynb#X31sZmlsZQ%3D%3D?line=22'>23</a>                 Where_IS GEOGRAPHY);""")
#
# DuplicateTable: relation "divvy_stations_realtime_status" already exists

# %%
db_connection.commit()

# %% [markdown]
# ### The following is the Heartbeat Loop - Pulls data from divvy every 2 minutes in order to get realtime updates for the different divvy stations

# %%
while True:
    # Get divvy statations status
    # Status is returned as a json reply

    response_stations_info = urlopen('https://gbfs.divvybikes.com/gbfs/en/station_information.json')

    response = urlopen('https://gbfs.divvybikes.com/gbfs/en/station_status.json')

    # Extract the body of the reply
    response_body = response.read()
    response_stations_info = response_stations_info.read()

    # Decode the format in json format
    stations_json = json.loads(response_body.decode("utf-8"))
    stations_info_json = json.loads(response_stations_info.decode("utf-8"))
    
    
    stations_dictionary = stations_json['data']
    stations_info_dictionary = stations_info_json['data']
    
    # load data file into a dataframe
    df__stations = pd.DataFrame(stations_dictionary['stations'])
    df__stations_info = pd.DataFrame(stations_info_dictionary['stations'])
    
    divvy_stations_realtime_status = pd.DataFrame(columns=[
                'altitude',
                'availableBikes',
                'availableDocks',
                'city',
                'id',
                'is_renting',
                'kioskType',
                'landMark',
                'lastCommunicationTime',
                'latitude',
                'location',
                'longitude',
                'postalCode',
                'stAddress1',
                'stAddress2',
                'stationName',
                'status',
                'statusKey',
                'statusValue',
                'testStation',
                'totalDocks' ])
    
    for x in range(len(df__stations.index)):
        if not ((df__stations['legacy_id'].iloc[x]).isnumeric()) :
            continue
        
        has_kiosk = df__stations_info['has_kiosk'][df__stations_info['legacy_id'] == df__stations['legacy_id'].iloc[x] ].values[0]
        row = [
            int(0),
            int(df__stations['num_bikes_available'].iloc[x]),
            int(df__stations['num_docks_available'].iloc[x]),
            'Chicago',
            df__stations['legacy_id'].iloc[x],
            bool(df__stations['is_renting'].iloc[x]),
            has_kiosk,
            'Chicago',
            datetime.strptime(time.ctime(int(df__stations['last_reported'].iloc[x])), "%a %b %d %H:%M:%S %Y").strftime("%Y-%m-%d %H:%M:%S"),
            float(df__stations_info['lat'][df__stations_info['legacy_id'] == df__stations['legacy_id'].iloc[x] ].values[0]),
            'Chicago',
            float(df__stations_info['lon'][df__stations_info['legacy_id'] == df__stations['legacy_id'].iloc[x] ].values[0]),
            60602,
            'Chicago',
            'Chicago',
            df__stations_info['name'][df__stations_info['legacy_id'] == df__stations['legacy_id'].iloc[x] ].values[0],
            'IN_SERVICE',
            1,
            'IN_SERVICE',
            False,
            int(df__stations_info['capacity'][df__stations_info['legacy_id'] == df__stations['legacy_id'].iloc[x] ].values[0])]
    
        divvy_stations_realtime_status.loc[len(divvy_stations_realtime_status)] = row

    print("\n", row, "\n")
        
    divvy_stations_realtime_status['altitude'] = divvy_stations_realtime_status['altitude'].astype(float)
    divvy_stations_realtime_status['availableBikes'] = divvy_stations_realtime_status['availableBikes'].astype(int)
    divvy_stations_realtime_status['availableDocks'] = divvy_stations_realtime_status['availableDocks'].astype(int)
    divvy_stations_realtime_status['city'] = divvy_stations_realtime_status.city.astype(str)
    divvy_stations_realtime_status['id'] = divvy_stations_realtime_status['id'].astype('int64')
    divvy_stations_realtime_status['is_renting'] = divvy_stations_realtime_status['is_renting'].astype(bool)
    divvy_stations_realtime_status['kioskType'] = divvy_stations_realtime_status['kioskType'].astype(str)
    divvy_stations_realtime_status['landMark'] = divvy_stations_realtime_status['landMark'].astype(str)
    divvy_stations_realtime_status['lastCommunicationTime'] = divvy_stations_realtime_status['lastCommunicationTime'].astype(str)
    divvy_stations_realtime_status['latitude'] = divvy_stations_realtime_status['latitude'].astype(float)
    divvy_stations_realtime_status['location'] = divvy_stations_realtime_status['location'].astype(str)
    divvy_stations_realtime_status['longitude'] = divvy_stations_realtime_status['longitude'].astype(float)
    divvy_stations_realtime_status['postalCode'] = divvy_stations_realtime_status['postalCode'].astype(int)
    divvy_stations_realtime_status['stAddress1'] = divvy_stations_realtime_status['stAddress1'].astype(str)
    divvy_stations_realtime_status['stAddress2'] = divvy_stations_realtime_status['stAddress2'].astype(str)
    divvy_stations_realtime_status['stationName'] = divvy_stations_realtime_status['stationName'].astype(str)
    divvy_stations_realtime_status['status'] = divvy_stations_realtime_status['status'].astype(str)
    divvy_stations_realtime_status['statusKey'] = divvy_stations_realtime_status['statusKey'].astype(int)
    divvy_stations_realtime_status['statusValue'] = divvy_stations_realtime_status['statusValue'].astype(str)
    divvy_stations_realtime_status['testStation'] = divvy_stations_realtime_status['testStation'].astype(bool)
    divvy_stations_realtime_status['totalDocks'] = divvy_stations_realtime_status['totalDocks'].astype(int)
    
    # lets store our data subset into a file
    # This way you have a copy of data stored in a file 
    # that you could use in case you want to debug a problem on the orginal data received

    divvy_stations_realtime_status.to_csv('divvy_stations_status.csv',sep=',', encoding='utf-8', index=False)
    
    # delete existing data in the table
    cursor.execute("DELETE FROM divvy_stations_realtime_status")
    db_connection.commit()

    
    # Now we will connect to the database and store divvy data
    with open('divvy_stations_status.csv', 'r') as f:
        reader = csv.reader(f)
        next(reader)  # Skip the header row.
        for row in reader:
            cursor.execute( "INSERT INTO divvy_stations_realtime_status VALUES (%s, %s, %s, %s, %s,    %s, %s, %s, %s,%s,   %s, %s, %s, %s,%s,   %s, %s, %s, %s,%s,  %s, NULL)", row)

    
    
    db_connection.commit()
    
    cursor.execute("UPDATE divvy_stations_realtime_status SET Where_IS = ST_POINT(latitude,longitude);")
    db_connection.commit()
    
    
    # Now we will connect to ElasticSearch database and store divvy data
    divvy_stations_realtime_status = divvy_stations_realtime_status.to_json(orient='records')
    divvy_stations_realtime_status = json.loads(divvy_stations_realtime_status)
    load(es,divvy_stations_realtime_status)
    
    
    # Sleep for 3 minutes; divvy updates its stations status every 2 minutes
    now = datetime.now()
    timedate = ( (str(now.now())).split('.')[0]).split(' ')[0] + ' ' + ((str(now.now())).split('.')[0]).split(' ')[1]
 
    print("\n", timedate, ' : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...', "\n")
    time.sleep(120)    
    continue
# Out:
#  [0, 0, 1, 'Chicago', '1715846705501012842', True, False, 'Chicago', '2022-09-06 13:40:27', 41.8662123, 'Chicago', -87.7184969, 60602, 'Chicago', 'Chicago', 'Public Rack - Independence Blvd & Roosevelt', 'IN_SERVICE', 1, 'IN_SERVICE', False, 1]
# /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: [types removal] Specifying types in bulk requests is deprecated.
#   warnings.warn(message, category=ElasticsearchWarning)
#  2022-11-20 19:32:16  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
#
#
#  [0, 0, 1, 'Chicago', '1715846705501012842', True, False, 'Chicago', '2022-09-06 13:40:27', 41.8662123, 'Chicago', -87.7184969, 60602, 'Chicago', 'Chicago', 'Public Rack - Independence Blvd & Roosevelt', 'IN_SERVICE', 1, 'IN_SERVICE', False, 1]
# /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: [types removal] Specifying types in bulk requests is deprecated.
#   warnings.warn(message, category=ElasticsearchWarning)
#  2022-11-20 19:34:23  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
#
#
#  [0, 0, 1, 'Chicago', '1715846705501012842', True, False, 'Chicago', '2022-09-06 13:40:27', 41.8662123, 'Chicago', -87.7184969, 60602, 'Chicago', 'Chicago', 'Public Rack - Independence Blvd & Roosevelt', 'IN_SERVICE', 1, 'IN_SERVICE', False, 1]
# /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: [types removal] Specifying types in bulk requests is deprecated.
#   warnings.warn(message, category=ElasticsearchWarning)
#  2022-11-20 19:36:29  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
#
#
#  [0, 0, 2, 'Chicago', '1674190634684001360', True, False, 'Chicago', '2022-09-06 20:12:45', 41.717059, 'Chicago', -87.559986, 60602, 'Chicago', 'Chicago', 'Public Rack - Torrence Ave & 98th St', 'IN_SERVICE', 1, 'IN_SERVICE', False, 2]
# /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: [types removal] Specifying types in bulk requests is deprecated.
#   warnings.warn(message, category=ElasticsearchWarning)
#  2022-11-20 19:38:36  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
#
#
#  [0, 0, 2, 'Chicago', '1674190634684001360', True, False, 'Chicago', '2022-09-06 20:12:45', 41.717059, 'Chicago', -87.559986, 60602, 'Chicago', 'Chicago', 'Public Rack - Torrence Ave & 98th St', 'IN_SERVICE', 1, 'IN_SERVICE', False, 2]
# /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: [types removal] Specifying types in bulk requests is deprecated.
#   warnings.warn(message, category=ElasticsearchWarning)
#  2022-11-20 19:40:42  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
#
#
#  [0, 0, 1, 'Chicago', '1715846705501012842', True, False, 'Chicago', '2022-09-06 13:40:27', 41.8662123, 'Chicago', -87.7184969, 60602, 'Chicago', 'Chicago', 'Public Rack - Independence Blvd & Roosevelt', 'IN_SERVICE', 1, 'IN_SERVICE', False, 1]
# /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: [types removal] Specifying types in bulk requests is deprecated.
#   warnings.warn(message, category=ElasticsearchWarning)
#  2022-11-20 19:42:49  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
#
#
#  [0, 0, 2, 'Chicago', '1674190634684001360', True, False, 'Chicago', '2022-09-06 20:12:45', 41.717059, 'Chicago', -87.559986, 60602, 'Chicago', 'Chicago', 'Public Rack - Torrence Ave & 98th St', 'IN_SERVICE', 1, 'IN_SERVICE', False, 2]
# /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: [types removal] Specifying types in bulk requests is deprecated.
#   warnings.warn(message, category=ElasticsearchWarning)
#  2022-11-20 19:44:56  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
#
#
#  [0, 0, 1, 'Chicago', '1715846705501012842', True, False, 'Chicago', '2022-09-06 13:40:27', 41.8662123, 'Chicago', -87.7184969, 60602, 'Chicago', 'Chicago', 'Public Rack - Independence Blvd & Roosevelt', 'IN_SERVICE', 1, 'IN_SERVICE', False, 1]
# /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: [types removal] Specifying types in bulk requests is deprecated.
#   warnings.warn(message, category=ElasticsearchWarning)
#  2022-11-20 19:47:02  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
#
#
#  [0, 0, 2, 'Chicago', '1674190634684001360', True, False, 'Chicago', '2022-09-06 20:12:45', 41.717059, 'Chicago', -87.559986, 60602, 'Chicago', 'Chicago', 'Public Rack - Torrence Ave & 98th St', 'IN_SERVICE', 1, 'IN_SERVICE', False, 2]
# /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: [types removal] Specifying types in bulk requests is deprecated.
#   warnings.warn(message, category=ElasticsearchWarning)
#  2022-11-20 19:49:08  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
#
#
#  [0, 0, 2, 'Chicago', '1674190634684001360', True, False, 'Chicago', '2022-09-06 20:12:45', 41.717059, 'Chicago', -87.559986, 60602, 'Chicago', 'Chicago', 'Public Rack - Torrence Ave & 98th St', 'IN_SERVICE', 1, 'IN_SERVICE', False, 2]
# /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: [types removal] Specifying types in bulk requests is deprecated.
#   warnings.warn(message, category=ElasticsearchWarning)
#  2022-11-20 19:51:14  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
#
#
#  [0, 0, 1, 'Chicago', '1715846705501012842', True, False, 'Chicago', '2022-09-06 13:40:27', 41.8662123, 'Chicago', -87.7184969, 60602, 'Chicago', 'Chicago', 'Public Rack - Independence Blvd & Roosevelt', 'IN_SERVICE', 1, 'IN_SERVICE', False, 1]
# /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: [types removal] Specifying types in bulk requests is deprecated.
#   warnings.warn(message, category=ElasticsearchWarning)
#  2022-11-20 19:53:21  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
#
#
#  [0, 0, 1, 'Chicago', '1715846705501012842', True, False, 'Chicago', '2022-09-06 13:40:27', 41.8662123, 'Chicago', -87.7184969, 60602, 'Chicago', 'Chicago', 'Public Rack - Independence Blvd & Roosevelt', 'IN_SERVICE', 1, 'IN_SERVICE', False, 1]
# /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: [types removal] Specifying types in bulk requests is deprecated.
#   warnings.warn(message, category=ElasticsearchWarning)
#  2022-11-20 19:55:27  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
#
#
#  [0, 0, 2, 'Chicago', '1674190634684001360', True, False, 'Chicago', '2022-09-06 20:12:45', 41.717059, 'Chicago', -87.559986, 60602, 'Chicago', 'Chicago', 'Public Rack - Torrence Ave & 98th St', 'IN_SERVICE', 1, 'IN_SERVICE', False, 2]
# /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: [types removal] Specifying types in bulk requests is deprecated.
#   warnings.warn(message, category=ElasticsearchWarning)
#  2022-11-20 19:57:33  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
#
#
#  [0, 0, 2, 'Chicago', '1674190634684001360', True, False, 'Chicago', '2022-09-06 20:12:45', 41.717059, 'Chicago', -87.559986, 60602, 'Chicago', 'Chicago', 'Public Rack - Torrence Ave & 98th St', 'IN_SERVICE', 1, 'IN_SERVICE', False, 2]
# /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: [types removal] Specifying types in bulk requests is deprecated.
#   warnings.warn(message, category=ElasticsearchWarning)
#  2022-11-20 19:59:39  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
#
#
#  [0, 0, 2, 'Chicago', '1674190634684001360', True, False, 'Chicago', '2022-09-06 20:12:45', 41.717059, 'Chicago', -87.559986, 60602, 'Chicago', 'Chicago', 'Public Rack - Torrence Ave & 98th St', 'IN_SERVICE', 1, 'IN_SERVICE', False, 2]
# /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: [types removal] Specifying types in bulk requests is deprecated.
#   warnings.warn(message, category=ElasticsearchWarning)
#  2022-11-20 20:01:45  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
#
#
#  [0, 0, 2, 'Chicago', '1674190634684001360', True, False, 'Chicago', '2022-09-06 20:12:45', 41.717059, 'Chicago', -87.559986, 60602, 'Chicago', 'Chicago', 'Public Rack - Torrence Ave & 98th St', 'IN_SERVICE', 1, 'IN_SERVICE', False, 2]
# /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: [types removal] Specifying types in bulk requests is deprecated.
#   warnings.warn(message, category=ElasticsearchWarning)
#  2022-11-20 20:03:52  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
#
#
#  [0, 0, 2, 'Chicago', '1674190634684001360', True, False, 'Chicago', '2022-09-06 20:12:45', 41.717059, 'Chicago', -87.559986, 60602, 'Chicago', 'Chicago', 'Public Rack - Torrence Ave & 98th St', 'IN_SERVICE', 1, 'IN_SERVICE', False, 2]
# /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: [types removal] Specifying types in bulk requests is deprecated.
#   warnings.warn(message, category=ElasticsearchWarning)
#  2022-11-20 20:05:59  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
#
#
#  [0, 0, 2, 'Chicago', '1674190634684001360', True, False, 'Chicago', '2022-09-06 20:12:45', 41.717059, 'Chicago', -87.559986, 60602, 'Chicago', 'Chicago', 'Public Rack - Torrence Ave & 98th St', 'IN_SERVICE', 1, 'IN_SERVICE', False, 2]
# /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: [types removal] Specifying types in bulk requests is deprecated.
#   warnings.warn(message, category=ElasticsearchWarning)
#  2022-11-20 20:08:06  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
#
#
#  [0, 0, 1, 'Chicago', '1715846705501012842', True, False, 'Chicago', '2022-09-06 13:40:27', 41.8662123, 'Chicago', -87.7184969, 60602, 'Chicago', 'Chicago', 'Public Rack - Independence Blvd & Roosevelt', 'IN_SERVICE', 1, 'IN_SERVICE', False, 1]
# /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: [types removal] Specifying types in bulk requests is deprecated.
#   warnings.warn(message, category=ElasticsearchWarning)
#  2022-11-20 20:10:14  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
#
#
#  [0, 0, 2, 'Chicago', '1674190634684001360', True, False, 'Chicago', '2022-09-06 20:12:45', 41.717059, 'Chicago', -87.559986, 60602, 'Chicago', 'Chicago', 'Public Rack - Torrence Ave & 98th St', 'IN_SERVICE', 1, 'IN_SERVICE', False, 2]
# /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: [types removal] Specifying types in bulk requests is deprecated.
#   warnings.warn(message, category=ElasticsearchWarning)
#  2022-11-20 20:12:20  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
#
#
#  [0, 0, 2, 'Chicago', '1674190634684001360', True, False, 'Chicago', '2022-09-06 20:12:45', 41.717059, 'Chicago', -87.559986, 60602, 'Chicago', 'Chicago', 'Public Rack - Torrence Ave & 98th St', 'IN_SERVICE', 1, 'IN_SERVICE', False, 2]
# /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: [types removal] Specifying types in bulk requests is deprecated.
#   warnings.warn(message, category=ElasticsearchWarning)
#  2022-11-20 20:14:28  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
#
#
#  [0, 0, 2, 'Chicago', '1674190634684001360', True, False, 'Chicago', '2022-09-06 20:12:45', 41.717059, 'Chicago', -87.559986, 60602, 'Chicago', 'Chicago', 'Public Rack - Torrence Ave & 98th St', 'IN_SERVICE', 1, 'IN_SERVICE', False, 2]
# /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# /Users/mingxi/opt/anaconda3/lib/python3.9/site-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: [types removal] Specifying types in bulk requests is deprecated.
#   warnings.warn(message, category=ElasticsearchWarning)
#  2022-11-20 20:16:34  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...

# %%
# close connection at the end of the script

db_connection.close()
